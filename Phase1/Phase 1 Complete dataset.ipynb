# %% [markdown]
# **PHASE - 1**

# %% [markdown]
# **IMPORTING NECESSARY LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Loading Census Dataset 2001 to 2012**

# %%
# Importing Census Dataset 2001 to 2012
census=pd.read_csv('census 2001 TO 2012 full.csv')
# fetching top 5 data of Census
census.head()
# Out:
#    S.no              State  Year   Total Population  Male Population  \
# 0     1  Jammu and Kashmir   2001          10069917          5300574
# 1     2   Himachal Pradesh   2001           6077248          3085256
# 2     3             Punjab   2001          24289296         12963362
# 3     4         Chandigarh   2001            900914           508224
# 4     5        Uttaranchal   2001           8479562          4316401
#
#    Female Population  Total_Literacy in %  Males_Literacy in %  \
# 0            4769343                54.46                65.75
# 1            2991992                77.13                86.02
# 2           11325934                69.95                75.63
# 3             392690                81.76                85.65
# 4            4163161                72.28                84.01
#
#    Females_Literacy in %  Total Literacy  Male Literacy  Female Literacy  \
# 0                  41.82         5484077        3485127          1994539
# ...

# %%
# fetching bottom 5 data of Census
census.tail()
# Out:
#      S.no                       State  Year   Total Population  \
# 415   416                 Lakshadweep   2012             71581
# 416   417                      Kerala   2012          37611095
# 417   418                  Tamil Nadu   2012          73371796
# 418   419                 Pondicherry   2012           1150388
# 419   420  Andaman & Nicobar Islands*   2012            420857
#
#      Male Population  Female Population  Total_Literacy in %  \
# 415            31985              39597                93.37
# 416         15899410           21711685                97.00
# 417         33947265           39424531                78.38
# 418           567746             582642                86.94
# 419           198359             222498                86.61
#
#      Males_Literacy in %  Females_Literacy in %  Total Literacy  \
# 415               100.47                  86.16           66835
# 416               101.60                  92.81        36482762
# ...

# %%
# fetching random data of Census
census.sample(2)
# Out:
#      S.no     State  Year   Total Population  Male Population  \
# 2       3    Punjab   2001          24289296         12963362
# 362   363  Nagaland   2011           2318121          1068023
#
#      Female Population  Total_Literacy in %  Males_Literacy in %  \
# 2             11325934                69.95                75.63
# 362            1250098                71.18                76.88
#
#      Females_Literacy in %  Total Literacy  Male Literacy  Female Literacy  \
# 2                    63.55        16990363        9804191          7197631
# 362                  65.09         1650039         821096           813689
#
#     Area in SQKM  Literacy Rate
# 2         50,362            700
# 362       16,579            712

# %% [markdown]
# **Loading Crime Dataset 2001 to 2012**

# %%
# Importing Crime Dataset 2001 to 2012
crime=pd.read_csv('TOTAL CRIMES 2001-2012.csv')
crime.head()
# Out:
#                State  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     Andhra Pradesh  2001    2602               1555
# 1  Arunachal Pradesh  2001      83                 53
# 2              Assam  2001    1356                481
# 3              Bihar  2001    3643               3419
# 4        Chhatisgarh  2001     880                529
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                        136   871               0
# 1                                          3    33               0
# 2                                         40   817               0
# 3                                        250   888               0
# 4                                         45   959               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  \
# 0         871                    1182
# 1          33                      83
# 2         817                    1480
# 3         888                    2159
# ...

# %%
# fetching bottom 5 data of Crime
crime.tail()
# Out:
#                     State  YEAR  MURDER  ATTEMPT TO MURDER  \
# 415  Dadra & Nagar Haveli  2012       7                  2
# 416           Daman & Diu  2012       3                  5
# 417                 Delhi  2012     521                439
# 418           Lakshadweep  2012       0                  0
# 419           Pondicherry  2012      29                 27
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 415                                          0     3               0
# 416                                          0     5               0
# 417                                         82   706               0
# 418                                          0     0               0
# 419                                         12    13               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  \
# 415           3                      13
# 416           5                       3
# 417         706                    3970
# ...

# %%
# fetching random data of Crime
crime.sample(2)
# Out:
#                  State  YEAR  MURDER  ATTEMPT TO MURDER  \
# 152             Kerala  2005     388                341
# 114  Jammu and Kashmir  2004     816               1112
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 152                                         88   478               0
# 114                                         29   218               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  \
# 152         478                     226
# 114         218                     735
#
#      KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS  ...  ARSON  \
# 152                                          129  ...    456
# 114                                          632  ...    320
#
#      HURT/GREVIOUS HURT  DOWRY DEATHS  \
# 152               18302            21
# 114                 334             9
#
#      ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 152                                               2339
# ...

# %% [markdown]
# # Merging both Dataset

# %%
df=pd.merge(census,crime,on='State',how='left')

# %%
df
# Out:
#       S.no                       State  Year   Total Population  \
# 0        1           Jammu and Kashmir   2001          10069917
# 1        1           Jammu and Kashmir   2001          10069917
# 2        1           Jammu and Kashmir   2001          10069917
# 3        1           Jammu and Kashmir   2001          10069917
# 4        1           Jammu and Kashmir   2001          10069917
# ...    ...                         ...    ...               ...
# 5035   420  Andaman & Nicobar Islands*   2012            420857
# 5036   420  Andaman & Nicobar Islands*   2012            420857
# 5037   420  Andaman & Nicobar Islands*   2012            420857
# 5038   420  Andaman & Nicobar Islands*   2012            420857
# 5039   420  Andaman & Nicobar Islands*   2012            420857
#
#       Male Population  Female Population  Total_Literacy in %  \
# 0             5300574            4769343                54.46
# 1             5300574            4769343                54.46
# ...

# %%
df.columns
# Out:
# Index(['S.no', 'State', 'Year ', 'Total Population', 'Male Population',
#        'Female Population', 'Total_Literacy in %', 'Males_Literacy in %',
#        'Females_Literacy in %', 'Total Literacy', 'Male Literacy',
#        'Female Literacy', 'Area in SQKM', 'Literacy Rate', 'YEAR', 'MURDER',
#        'ATTEMPT TO MURDER', 'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER',
#        'RAPE', 'CUSTODIAL RAPE', 'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
# ...

# %%
census.columns
# Out:
# Index(['S.no', 'State', 'Year ', 'Total Population', 'Male Population',
#        'Female Population', 'Total_Literacy in %', 'Males_Literacy in %',
#        'Females_Literacy in %', 'Total Literacy', 'Male Literacy',
#        'Female Literacy', 'Area in SQKM', 'Literacy Rate'],
#       dtype='object')

# %%
df.drop_duplicates(subset=['State', 'Year ', 'Total Population', 'Male Population',
       'Female Population', 'Total_Literacy in %', 'Males_Literacy in %',
       'Females_Literacy in %', 'Total Literacy', 'Male Literacy',
       'Female Literacy', 'Area in SQKM'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 420 entries, 0 to 5028
# Data columns (total 45 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   S.no                                                 420 non-null    int64
#  1   State                                                420 non-null    object
#  2   Year                                                 420 non-null    int64
#  3   Total Population                                     420 non-null    int64
#  4   Male Population                                      420 non-null    int64
#  5   Female Population                                    420 non-null    int64
#  6   Total_Literacy in %                                  420 non-null    float64
#  7   Males_Literacy in %                                  420 non-null    float64
# ...

# %%
df
# Out:
#       S.no                       State  Year   Total Population  \
# 0        1           Jammu and Kashmir   2001          10069917
# 12       2            Himachal Pradesh   2001           6077248
# 24       3                      Punjab   2001          24289296
# 36       4                  Chandigarh   2001            900914
# 48       5                 Uttaranchal   2001           8479562
# ...    ...                         ...    ...               ...
# 4980   416                 Lakshadweep   2012             71581
# 4992   417                      Kerala   2012          37611095
# 5004   418                  Tamil Nadu   2012          73371796
# 5016   419                 Pondicherry   2012           1150388
# 5028   420  Andaman & Nicobar Islands*   2012            420857
#
#       Male Population  Female Population  Total_Literacy in %  \
# 0             5300574            4769343                54.46
# 12            3085256            2991992                77.13
# ...

# %%
df.to_csv('Phase2Data.csv')

# %%
df=pd.read_csv('Phase2Data.csv')

# %%
df
# Out:
#      Unnamed: 0  S.no                       State  Year   Total Population  \
# 0             0     1           Jammu and Kashmir   2001          10069917
# 1            12     2            Himachal Pradesh   2001           6077248
# 2            24     3                      Punjab   2001          24289296
# 3            36     4                  Chandigarh   2001            900914
# 4            48     5                 Uttaranchal   2001           8479562
# ..          ...   ...                         ...    ...               ...
# 415        4980   416                 Lakshadweep   2012             71581
# 416        4992   417                      Kerala   2012          37611095
# 417        5004   418                  Tamil Nadu   2012          73371796
# 418        5016   419                 Pondicherry   2012           1150388
# 419        5028   420  Andaman & Nicobar Islands*   2012            420857
#
#      Male Population  Female Population  Total_Literacy in %  \
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.to_csv('Phase2Data.csv')

# %% [markdown]
# **WHat We have Done in Phase 1---**
#
#         We have collected data from different websites and after scraping the data we have merged all the data and make CSV files of that Now in the next part we have Load the Total IPC Crimes data and merge webscraped merged data into that and we have drop the unnamed column which is not relevant for the procedding.
#
#         Now lets go to the Next Part where we make analysis of the data that we have.
