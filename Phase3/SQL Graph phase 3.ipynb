# %%
# Phase 3 SQL OPERATIONS GRAPH

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
ipc=pd.read_csv('murder rape ipc crimes.csv')

# %%
ipc
# Out:
#            state_ut  year    district  MAX(murder)
# 0     UTTAR PRADESH  2001       TOTAL         7601
# 1     UTTAR PRADESH  2002       TOTAL         6825
# 2     UTTAR PRADESH  2004       TOTAL         6126
# 3     UTTAR PRADESH  2005       TOTAL         5711
# 4     UTTAR PRADESH  2006       TOTAL         5480
# ..              ...   ...         ...          ...
# 995     MAHARASHTRA  2011  AHMEDNAGAR          107
# 996  MADHYA PRADESH  2011     GWALIOR          107
# 997           BIHAR  2011  SAMASTIPUR          107
# 998  ANDHRA PRADESH  2010      GUNTUR          107
# 999           BIHAR  2008    VAISHALI          106
#
# [1000 rows x 4 columns]

# %%
plt.figure(figsize=(15,8),facecolor='powderblue')
sns.lineplot(data=ipc, x='state_ut',y='MAX(murder)',hue='year',marker='o',linestyle='--',palette='husl')
plt.xlabel('STATE_UT')
plt.ylabel('MURDER')
plt.title('In WHICH STATE MAX MURDER HAPPEN')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8),facecolor='powderblue')
sns.lineplot(data=ipc,x='year',y='MAX(murder)',marker='o',linestyle='--',palette='viridis')
plt.xlabel('Year')
plt.ylabel('MURDER')
plt.title('MAX MURDER YEAR')
plt.show()

# %%
plt.figure(figsize=(20,8),facecolor='powderblue')
sns.lineplot(data=ipc,x='district',y='MAX(murder)',hue='year',palette='viridis')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8),facecolor='powderblue')
sns.lmplot(data=ipc,x='year',y='MAX(murder)',hue='state_ut',aspect=15/10)
plt.show()
